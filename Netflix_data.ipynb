# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'D:\covid_project\project_3\8. Netflix Dataset.csv', encoding = 'unicode_escape')

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.head(5)
# Out:
#   Show_Id Category  Title           Director
# 0      s1  TV Show     3%                NaN  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil  \
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration
# 0    August 14, 2020  TV-MA  4 Seasons  \
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df['Title'].nunique()
# Out:
# 7787

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df.isna().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df['Director'].nunique()
# Out:
# 4050

# %%
df['Director'].value_counts()
# Out:
# Director
# RaÃºl Campos, Jan Suter    18
# Marcus Raboy               16
# Jay Karas                  14
# Cathy Garcia-Molina        13
# Jay Chapman                12
#                            ..
# Lucien Jean-Baptiste        1
# Jason Krawczyk              1
# Quinn Lasher                1
# Elle Callahan               1
# Sam Dunn                    1
# Name: count, Length: 4050, dtype: int64

# %%
df[df['Director'] == 'Marcus Raboy']
# Out:
#      Show_Id Category                                              Title
# 550     s551    Movie       Anthony Jeselnik: Fire in the Maternity Ward  \
# 1543   s1544    Movie                      Cristela Alonzo: Lower Classy
# 1585   s1586    Movie               Dana Carvey: Straight White Male, 60
# 1705   s1706    Movie                      DeRay Davis: How to Act Black
# 3231   s3232    Movie                            Judd Apatow: The Return
# 3323   s3324    Movie                       Katt Williams: Kattpacalypse
# 3828   s3829    Movie                      Lynne Koplitz: Hormonal Beast
# 3945   s3946    Movie                            Marlon Wayans: Woke-ish
# 4124   s4125    Movie                  Miranda Sings Liveâ¦Your Welcome
# 4797   s4798  TV Show                   Patton Oswalt: I Love Everything
# 5320   s5320    Movie                          Ryan Hamilton: Happy Face
# 5816   s5816    Movie  Steve Martin and Martin Short: An Evening You ...
# ...

# %%
df[df['Category'] == 'TV Show']
# Out:
#      Show_Id Category                  Title              Director
# 0         s1  TV Show                     3%                   NaN  \
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7769   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7777   s7776  TV Show             Zoids Wild                   NaN
# 7779   s7778  TV Show            Zombie Dumb                   NaN
# 7781   s7780  TV Show              Zona Rosa                   NaN
# 7787   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    Cast
# 0     JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...  \
# ...

# %%
df['Director'].dropna(how = 'all', inplace = True)

# %%
df.shape
# Out:
# (7789, 11)

# %%
df['Director'].fillna(value = ' Unknown', inplace = True)

# %%
df.isna().sum()
# Out:
# Show_Id           0
# Category          0
# Title             0
# Director          0
# Cast            718
# Country         507
# Release_Date     10
# Rating            7
# Duration          0
# Type              0
# Description       0
# dtype: int64

# %%
df.drop(labels={'Description', 'Cast'}, axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Country', 'Release_Date',
#        'Rating', 'Duration', 'Type'],
#       dtype='object')

# %%
df.head(5)
# Out:
#   Show_Id Category  Title           Director        Country
# 0      s1  TV Show     3%            Unknown         Brazil  \
# 1      s2    Movie  07:19  Jorge Michel Grau         Mexico
# 2      s3    Movie  23:59       Gilbert Chan      Singapore
# 3      s4    Movie      9        Shane Acker  United States
# 4      s5    Movie     21     Robert Luketic  United States
#
#         Release_Date Rating   Duration
# 0    August 14, 2020  TV-MA  4 Seasons  \
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
#                                                 Type
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas

# %%
df['Country'].nunique()
# Out:
# 681

# %%
df['Country'].unique()
# Out:
# array(['Brazil', 'Mexico', 'Singapore', 'United States', 'Turkey',
#        'Egypt', 'India', 'Poland, United States', 'Thailand', 'Nigeria',
#        nan, 'Norway, Iceland, United States', 'United Kingdom', 'Japan',
#        'South Korea', 'Italy', 'Canada', 'Indonesia', 'Romania', 'Spain',
#        'Iceland', 'South Africa, Nigeria', 'France',
#        'United States, South Africa', 'Portugal, Spain',
#        'Hong Kong, China, Singapore', 'United States, Germany',
#        'South Africa, China, United States', 'Argentina',
#        'United States, France, Serbia', 'Germany',
#        'Denmark, France, Poland', 'Poland', 'Kenya',
#        'New Zealand, United Kingdom', 'Pakistan', 'Australia',
#        'Australia, United States', 'Mexico, United States',
#        'United States, China', 'China, Hong Kong', 'Taiwan',
#        'United States, United Kingdom', 'France, South Korea, Japan',
#        'United States, Canada', 'United Kingdom, United States',
# ...

# %%
value = df[df['Country'].duplicated()]
value
# Out:
#      Show_Id Category                                    Title
# 4         s5    Movie                                       21  \
# 7         s8    Movie                                      187
# 9        s10    Movie                                     1920
# 10       s11    Movie                                     1922
# 12       s13  TV Show                                     1994
# ...      ...      ...                                      ...
# 7783   s7782    Movie                                     Zoom
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                   Director                                Country
# 4           Robert Luketic                          United States  \
# 7           Kevin Reynolds                          United States
# ...

# %%
df['Country'].value_counts().head(10).plot(kind = 'bar', figsize = (10,8), style = 'dark')
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# united having the highest number of releases in netflix

# %%
df['Country'].fillna(value = 'United States', inplace = True)

# %%
df['Country'].value_counts().head(10).plot(kind = 'bar', figsize = (10,8), style = 'darkgride')
# Out:
# <Axes: xlabel='Country'>

# %%
df.isna().sum()
# Out:
# Show_Id          0
# Category         0
# Title            0
# Director         0
# Country          0
# Release_Date    10
# Rating           7
# Duration         0
# Type             0
# dtype: int64

# %%
df['Release_Date'].nunique()
# Out:
# 1565

# %%
df[df['Release_Date'].duplicated()]
# Out:
#      Show_Id Category                                    Title
# 22       s23    Movie                 âMaj Rati ââKeteki  \
# 23       s24    Movie                            âMayurakshi
# 37       s38    Movie                               #Selfie 69
# 42       s43    Movie             Ãok Filim Hareketler Bunlar
# 46       s47    Movie                         1 Chance 2 Dance
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                            Country
# 22    Santwana Bardoloi                                              India  \
# ...

# %%
df['Release_Date'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Release_Date'>

# %%
df['Release_Date'].fillna(value = 'UNKNOWN', inplace = True)

# %%
df['Rating'].nunique()
# Out:
# 14

# %%
df[df['Rating'].duplicated()].count()
# Out:
# Show_Id         7774
# Category        7774
# Title           7774
# Director        7774
# Country         7774
# Release_Date    7774
# Rating          7768
# Duration        7774
# Type            7774
# dtype: int64

# %%
df.shape
# Out:
# (7789, 9)

# %%
df['Rating'].value_counts()
# Out:
# Rating
# TV-MA       2865
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: count, dtype: int64

# %%
df['Rating'].fillna(value = 'TV-MA', inplace = True)

# %%
df.isna().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Country', 'Release_Date',
#        'Rating', 'Duration', 'Type'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director Country       Release_Date
# 0      s1  TV Show     3%            Unknown  Brazil    August 14, 2020  \
# 1      s2    Movie  07:19  Jorge Michel Grau  Mexico  December 23, 2016
#
#   Rating   Duration                                               Type
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies

# %%
ax = df.groupby(['Category','Release_Date'], as_index = False)['Rating'].count().sort_values(by = 'Rating', ascending = False).head(30)
sns.barplot(x = 'Release_Date', y = 'Rating', hue = 'Category', data = ax, palette = 'rocket')
sns.set(rc={'figure.figsize':(30,6)})
